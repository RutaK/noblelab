# %%
#scrape proc airs and proc blanks separately

from openpyxl import load_workbook


import numpy as np

import csv
from scipy import stats
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
import matplotlib

# %%
#filtered ones by volumes
df = pd.read_excel(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\neon_procs_filt.xlsx", header=0, index_col=0)

#all proc data
xf = pd.read_excel(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\proc_airs_ne.xlsx", header=0, index_col=0)

# %%
# specify keywords we will be looking for to classify data
keywords_proc_air = df.index.tolist()

# %%
#filter data to include proc airs and drop proc banks
f = xf.dropna(axis = 0, subset=['Sample_ID'])

# %%
# Selecting which proc airs we want from Quad data process sheet
# row number from which to start and end (end number currently to include ALL)
row_start = 0
row_end = 200
z = xf.iloc[row_start:row_end]
z['Sample_copy'] = z.index

z['Proc_air'] = np.nan

#filter data to include proc airs and drop proc banks
z = z.dropna(axis = 0, subset=['Sample_copy'])
for index, row in z.iterrows():
    if any(s in row.Sample_copy for s in keywords_proc_air) == True:
        z['Proc_air'].loc[index] = 'Proc_air'
    #if any(s in row.Sample_copy for s in keywords_proc_air) == False:
        #z['Proc_air'].loc[index] = np.nan
z = z.dropna(axis = 0, subset=['Proc_air'])
print_into_excel(z)
# Out:
# C:\Users\eart0477\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\eart0477\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\eart0477\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
print(keywords_proc_air)
# Out:
# ['Proc Air 156 Sample 1030', 'Proc Air 157', 'Proc Air 159', 'Proc Air 162', 'Proc Air 166', 'Proc air 264 Sample 1804', 'Proc air 265 Sample 1805', 'Proc air 266 Sample 1806', 'Proc air 267 Sample 1807', 'Proc air 268 Sample 1808', 'Proc Air 283; Sample 1859', 'Proc Air 286; Sample 1872', 'Proc Air 130', 'Proc Air 132', 'Proc Air 133', 'Proc air 262 Sample 1801', 'Proc air 263 Sample 1802', 'Proc air 273 Sample 185', 'Proc air 274 Sample 1817', 'Proc air 275 Sample 1818', 'Proc air 276 Sample 1819', 'Proc Air 282; Sample 1583', 'Proc Air 284; Sample 1862', 'Proc Air 285; Sample 1867', 'Proc Air 287; Sample 1883', 'Proc Air 308 sample 2001', 'Proc Air 311 Sample 2009', 'Proc Air 314 Sample 2023', 'Proc Air 161', 'Proc Air 167 - Sample 1109', 'Proc Air 168 - Sample 1110', 'Proc Air 172 - Sample 1136', 'Proc Air 177; CAL; Sample 1179']

# %%
print(z)
# Out:
#                                              Date                       notes  \
# Sample_ID
# Proc Air 130                  2018-05-12 15:45:43                         NaN
# Proc Air 132                  2018-06-12 13:53:34                         NaN
# Proc Air 133                  2018-08-12 11:53:19                         NaN
# Proc Air 156 Sample 1030                 10/28/19                         NaN
# Proc Air 157                  2019-12-11 00:00:00                         NaN
# Proc Air 167 - Sample 1109                    NaN                  Ne: Allgas
# Proc Air 168 - Sample 1110                    NaN                  Ne: Allgas
# Proc Air 172 - Sample 1136                    NaN  40.5 ± 0.7 mV; CAL; Allgas
# Proc Air 283; Sample 1859     2021-12-06 13:33:13                     UNKNOWN
# Proc Air 284; Sample 1862    6/13/2021 5:52:38 PM                     UNKNOWN
# Proc Air 285; Sample 1867    6/17/2021 2:21:33 PM                     UNKNOWN
# Proc Air 286; Sample 1872    6/21/2021 1:03:29 PM                     UNKNOWN
# Proc Air 287; Sample 1883     2021-05-07 19:42:42                     UNKNOWN
# Proc Air 308 sample 2001      2021-10-24 00:00:00                         NaN
# Proc Air 311 Sample 2009      2021-10-28 00:00:00                         NaN
#
#                              Unnamed: 3     20Ne (Ax)      20Ne (H2)  \
# Sample_ID
# Proc Air 130                        NaN           NaN    8879.721904
# Proc Air 132                        NaN           NaN    8828.298892
# Proc Air 133                        NaN           NaN    8759.047451
# Proc Air 156 Sample 1030            NaN   6385.782130    6559.261971
# Proc Air 157                   0.028562   9560.165948    9820.331860
# Proc Air 167 - Sample 1109          NaN           NaN  153510.977377
# Proc Air 168 - Sample 1110          NaN           NaN  154813.406369
# Proc Air 172 - Sample 1136     0.028582           NaN  147443.344575
# Proc Air 283; Sample 1859           NaN           NaN   80250.176953
# Proc Air 284; Sample 1862           NaN           NaN  255237.690842
# Proc Air 285; Sample 1867           NaN           NaN  505680.555217
# Proc Air 286; Sample 1872           NaN           NaN   82384.062301
# Proc Air 287; Sample 1883           NaN  48744.642422  244682.690325
# Proc Air 308 sample 2001            NaN           NaN            NaN
# Proc Air 311 Sample 2009            NaN           NaN            NaN
#
#                                      22Ne        21Ne    21Ne (ax)  \
# Sample_ID
# Proc Air 130                          NaN  947.639661          NaN
# Proc Air 132                          NaN  942.189509          NaN
# Proc Air 133                          NaN  936.084704          NaN
# Proc Air 156 Sample 1030       661.468364   17.747083    18.898516
# Proc Air 157                   990.612465   26.467720    28.293630
# Proc Air 167 - Sample 1109            NaN    1.871351     1.197352
# Proc Air 168 - Sample 1110            NaN    1.900248     1.232979
# Proc Air 172 - Sample 1136   14863.128083         NaN   424.817107
# Proc Air 283; Sample 1859     8095.936713  193.998568   231.042379
# Proc Air 284; Sample 1862    25743.204322    4.500600   736.686721
# Proc Air 285; Sample 1867    50909.346447         NaN  1461.014236
# Proc Air 286; Sample 1872     8302.752883  195.290442   237.567874
# Proc Air 287; Sample 1883    24675.598090    4.834080   707.392149
# Proc Air 308 sample 2001              NaN         NaN          NaN
# Proc Air 311 Sample 2009              NaN         NaN          NaN
#
#                                    40Ar       38Ar  ...  \
# Sample_ID                                           ...
# Proc Air 130                  25.400171  27.152852  ...
# Proc Air 132                  25.160817  27.076315  ...
# Proc Air 133                  24.987176  26.863737  ...
# Proc Air 156 Sample 1030      13.694809   0.000597  ...
# Proc Air 157                  18.317903   0.047656  ...
# Proc Air 167 - Sample 1109   110.320330   0.410375  ...
# Proc Air 168 - Sample 1110    33.366335   0.257316  ...
# Proc Air 172 - Sample 1136    32.126548   0.322114  ...
# Proc Air 283; Sample 1859     -3.289293   0.121880  ...
# Proc Air 284; Sample 1862     79.393056   0.238161  ...
# Proc Air 285; Sample 1867    512.774946   0.575129  ...
# Proc Air 286; Sample 1872     24.164423   0.130975  ...
# Proc Air 287; Sample 1883     -6.184061   0.299170  ...
# Proc Air 308 sample 2001            NaN        NaN  ...
# Proc Air 311 Sample 2009            NaN        NaN  ...
#
#                              20Ne/22Ne (++40Ar Corr) PB  Air-Corr 20Ne/22Ne   \
# Sample_ID
# Proc Air 130                                        NaN                  NaN
# Proc Air 132                                        NaN                  NaN
# Proc Air 133                                        NaN                  NaN
# Proc Air 156 Sample 1030                            NaN                  NaN
# Proc Air 157                                        NaN                  NaN
# Proc Air 167 - Sample 1109                          NaN                  NaN
# Proc Air 168 - Sample 1110                          NaN                  NaN
# Proc Air 172 - Sample 1136                          NaN                  NaN
# Proc Air 283; Sample 1859                           NaN                  NaN
# Proc Air 284; Sample 1862                           NaN                  NaN
# Proc Air 285; Sample 1867                           NaN                  NaN
# Proc Air 286; Sample 1872                           NaN                  NaN
# Proc Air 287; Sample 1883                           NaN                  NaN
# Proc Air 308 sample 2001                            NaN                  NaN
# Proc Air 311 Sample 2009                            NaN                  NaN
#
#                              error.6  21/22 Ne  error.7  Air corr 21/22 Ne  \
# Sample_ID
# Proc Air 130                     NaN       NaN      NaN                NaN
# Proc Air 132                     NaN       NaN      NaN                NaN
# Proc Air 133                     NaN       NaN      NaN                NaN
# Proc Air 156 Sample 1030         NaN       NaN      NaN                NaN
# Proc Air 157                     NaN       NaN      NaN                NaN
# Proc Air 167 - Sample 1109       NaN       NaN      NaN                NaN
# Proc Air 168 - Sample 1110       NaN       NaN      NaN                NaN
# Proc Air 172 - Sample 1136       NaN       NaN      NaN                NaN
# Proc Air 283; Sample 1859        NaN       NaN      NaN                NaN
# Proc Air 284; Sample 1862        NaN       NaN      NaN                NaN
# Proc Air 285; Sample 1867        NaN       NaN      NaN                NaN
# Proc Air 286; Sample 1872        NaN       NaN      NaN                NaN
# Proc Air 287; Sample 1883        NaN       NaN      NaN                NaN
# Proc Air 308 sample 2001         NaN       NaN      NaN                NaN
# Proc Air 311 Sample 2009         NaN       NaN      NaN                NaN
#
#                              21Ne/22Ne error  Unnamed: 76  Proc_air  \
# Sample_ID
# Proc Air 130                             NaN          NaN  Proc_air
# Proc Air 132                             NaN          NaN  Proc_air
# Proc Air 133                             NaN          NaN  Proc_air
# Proc Air 156 Sample 1030                 NaN          NaN  Proc_air
# Proc Air 157                             NaN          NaN  Proc_air
# Proc Air 167 - Sample 1109               NaN          NaN  Proc_air
# Proc Air 168 - Sample 1110               NaN          NaN  Proc_air
# Proc Air 172 - Sample 1136               NaN          NaN  Proc_air
# Proc Air 283; Sample 1859                NaN          NaN  Proc_air
# Proc Air 284; Sample 1862                NaN          NaN  Proc_air
# Proc Air 285; Sample 1867                NaN          NaN  Proc_air
# Proc Air 286; Sample 1872                NaN          NaN  Proc_air
# Proc Air 287; Sample 1883                NaN          NaN  Proc_air
# Proc Air 308 sample 2001                 NaN          NaN  Proc_air
# Proc Air 311 Sample 2009                 NaN          NaN  Proc_air
#
#                                              Sample_copy
# Sample_ID
# Proc Air 130                                Proc Air 130
# Proc Air 132                                Proc Air 132
# Proc Air 133                                Proc Air 133
# Proc Air 156 Sample 1030        Proc Air 156 Sample 1030
# Proc Air 157                                Proc Air 157
# Proc Air 167 - Sample 1109    Proc Air 167 - Sample 1109
# Proc Air 168 - Sample 1110    Proc Air 168 - Sample 1110
# Proc Air 172 - Sample 1136   Proc Air 172 - Sample 1136
# Proc Air 283; Sample 1859      Proc Air 283; Sample 1859
# Proc Air 284; Sample 1862      Proc Air 284; Sample 1862
# Proc Air 285; Sample 1867      Proc Air 285; Sample 1867
# Proc Air 286; Sample 1872      Proc Air 286; Sample 1872
# Proc Air 287; Sample 1883      Proc Air 287; Sample 1883
# Proc Air 308 sample 2001        Proc Air 308 sample 2001
# Proc Air 311 Sample 2009        Proc Air 311 Sample 2009
#
# [15 rows x 78 columns]

# %%
def print_into_excel(dtp):


        book = load_workbook(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\test.xlsx")
        writer = pd.ExcelWriter(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\test.xlsx", engine='openpyxl')
        writer.book = book
        writer.sheets = {ws.title: ws for ws in book.worksheets}

        for sheetname in writer.sheets:
            dtp.to_excel(writer, sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, index=True,
                         header=True)
        writer.save()

        return
