# %%
from openpyxl import load_workbook

import numpy as np

import csv
from scipy import stats
import pandas as pd
import seaborn as sns
import plotly.express as px

import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_excel(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\proc_ais_he1.xlsx", header=0, index_col=0)
pd.to_datetime(df['Date'], errors='coerce')
# Out:
# Run #
# Proc Air 002                    2016-12-16 14:54:26
# Proc Air 003                    2016-12-16 17:29:27
# Proc Air 069                    2016-12-24 16:26:19
# Proc Air 070                    2016-12-24 20:29:20
# Proc Air 73                     2017-01-08 19:14:56
#                                         ...
# Proc Air 317 Sample 2058 mani   2021-11-29 00:16:00
# Proc Air 318 Sample 2060 mani   2021-11-29 16:55:00
# Proc Air 320 Sample 2071        2021-12-06 15:37:00
# Proc Air 321 Sample 2081        2021-12-08 18:17:00
# Proc Air 322 Sample 2099        2021-12-15 11:44:00
# Name: Date, Length: 417, dtype: datetime64[ns]

# %%
ratio1= '3He/4He R/Ra'

df = df.dropna(axis = 0, subset=[ratio1, 'Date'])

# %%
df = df.loc[df[ratio1]< 0.82]
df = df.loc[df[ratio1]> 0.71]

df = df.loc[df['3He']>0.001]

# %%
fig = px.scatter(df, x=df['Date'], y=df['3He/4He'], log_y=False)
#fig.add_scatter(x=dft.index, y=f['fa/mbar'], mode='scatter', name='Nitrogen')



fig.update_layout(
    title="3He/4He procedural air standards",
    xaxis_title="Date",
    yaxis_title="3He/4He ")
fig.update_layout(yaxis={ 'tickformat':'e', 'rangemode': 'tozero'})

fig.update_yaxes(range=[0,1.6e-6]) 
fig.update_xaxes

fig.show()
# Out:
# <div>
#
#
#             <div id="e8d17192-e3a4-4ec6-b555-f8bdb1504148" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e8d17192-e3a4-4ec6-b555-f8bdb1504148")) {
#                     Plotly.newPlot(
#                         'e8d17192-e3a4-4ec6-b555-f8bdb1504148',
# ...

# %%
def print_into_excel(dtp):


        book = load_workbook(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\test2.xlsx")
        writer = pd.ExcelWriter(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\test2.xlsx", engine='openpyxl')
        writer.book = book
        writer.sheets = {ws.title: ws for ws in book.worksheets}

        for sheetname in writer.sheets:
            dtp.to_excel(writer, sheet_name=sheetname, startrow=writer.sheets[sheetname].max_row, index=True,
                         header=True)
        writer.save()

        return

# %%
print_into_excel(df)

# %%
df = pd.read_excel(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\proc_airs_ne.xlsx", header=0, index_col=0)
pd.to_datetime(df['Date'], errors='coerce')
# Out:
# Sample_ID
# Proc Air 002                 2017-05-13 17:31:54
# Proc Air 003                 2017-05-13 19:59:30
# Proc Air 004                 2017-05-16 19:11:10
# Proc Air 005                 2017-05-18 20:07:28
# Proc Air 006                 2017-05-18 22:04:59
#                                      ...
# Proc Air 304 Sample 1985     2021-10-14 16:11:02
# Proc Air 305 Sample 1987     2021-10-15 15:20:18
# Proc Air 306 Sample 1988     2021-10-18 11:24:18
# Laser proc air Sample 2052   2021-11-25 10:10:28
# Proc Air 320 Sample 2071     2021-06-12 16:22:07
# Name: Date, Length: 197, dtype: datetime64[ns]

# %%
ratio1= '20Ne/22Ne'
ratio2= '21Ne/22Ne'

df = df.dropna(axis = 0, subset=[ratio1, ratio2, 'Date'])
df = df.loc[df[ratio1]< 10]
df = df.loc[df[ratio1]> 9.1]
df = df.loc[df[ratio2]> 0.01]

#df = df.loc[df['3He']>0.001]

# %%
#initial plot
fig1 = px.scatter(df, x=df['Date'], y=df[ratio1], log_y=False)
fig1.update_layout(
    title="20Ne/22Ne procedural air standards",
    xaxis_title="Date",
    yaxis_title=ratio1)
fig1.update_layout(yaxis={ 'rangemode': 'tozero'})

fig1.update_yaxes(range=[8.6, 10.5]) 
fig1.update_xaxes

fig1.show()
# Out:
# <div>
#
#
#             <div id="4a18e1c9-358f-4642-9ff0-955bb1f55307" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a18e1c9-358f-4642-9ff0-955bb1f55307")) {
#                     Plotly.newPlot(
#                         '4a18e1c9-358f-4642-9ff0-955bb1f55307',
# ...

# %%
#initial plot
fig2 = px.scatter(df, x=df['Date'], y=df[ratio2], log_y=False)
fig2.update_layout(
    title="20Ne/22Ne procedural air standards",
    xaxis_title="Date",
    yaxis_title=ratio2)
fig2.update_layout(yaxis={ 'rangemode': 'tozero'})

#fig.update_yaxes(range=[8.6, 10.5]) 
fig2.update_xaxes

fig2.show()
# Out:
# <div>
#
#
#             <div id="65606a57-a5da-4c1c-822b-5a8eae8f3b15" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("65606a57-a5da-4c1c-822b-5a8eae8f3b15")) {
#                     Plotly.newPlot(
#                         '65606a57-a5da-4c1c-822b-5a8eae8f3b15',
# ...

# %%
df = pd.read_excel(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\proc_airs_ar.xlsx", header=0, index_col=0)
pd.to_datetime(df['Date'], errors='coerce')
# Out:
# Run #
# Proc Air 77                              2017-01-21 16:05:38
# Proc Air 79                              2017-07-02 12:55:52
# Proc Air 80                                              NaT
# Proc Air 81                                              NaT
# Proc Air 82                              2017-09-02 23:15:47
#                                                  ...
# Proc Air 308 sample 2001                 2021-10-24 00:00:00
# Proc Air 311 Sample 2009                 2021-10-28 00:00:00
# Proc Air 312 Sample 2010 (Annie's exp)   2021-10-29 00:00:00
# Laser proc air Sample 2052               2021-11-25 11:09:18
# Proc Air 320 Sample 2071                 2021-06-12 17:18:27
# Name: Date, Length: 188, dtype: datetime64[ns]

# %%
ratio1= '40Ar/36Ar'
ratio2= '38Ar/36Ar'

df = df.dropna(axis = 0, subset=[ratio1, ratio2, 'Date'])
df = df.loc[df[ratio1]< 400]
df = df.loc[df[ratio1]> 250]
df = df.loc[df[ratio2]<0.3]

df = df.loc[df[ratio2]>0.12]

# %%
#initial plot
fig3 = px.scatter(df, x=df['Date'], y=df[ratio1], log_y=False)
fig3.update_layout(
    title="40Ar/36Ar procedural air standards",
    xaxis_title="Date",
    yaxis_title=ratio1)
fig3.update_layout(yaxis={ 'rangemode': 'tozero'})

fig3.update_yaxes(range=[200, 500]) 
fig3.update_xaxes

fig3.show()
# Out:
# <div>
#
#
#             <div id="39584a40-0ab3-4e63-8727-d0b43fc03768" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("39584a40-0ab3-4e63-8727-d0b43fc03768")) {
#                     Plotly.newPlot(
#                         '39584a40-0ab3-4e63-8727-d0b43fc03768',
# ...

# %%
#initial plot
fig4 = px.scatter(df, x=df['Date'], y=df[ratio2], log_y=False)
fig4.update_layout(
    title="38Ar/36Ar procedural air standards",
    xaxis_title="Date",
    yaxis_title=ratio2)
fig4.update_layout(yaxis={ 'rangemode': 'tozero'})

fig4.update_yaxes(range=[0.1, 0.35]) 
fig4.update_xaxes

fig4.show()
# Out:
# <div>
#
#
#             <div id="9f61ffb6-ddea-4940-9d14-bf1dcda7bea7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f61ffb6-ddea-4940-9d14-bf1dcda7bea7")) {
#                     Plotly.newPlot(
#                         '9f61ffb6-ddea-4940-9d14-bf1dcda7bea7',
# ...

# %%
df = pd.read_excel(r"C:\Users\eart0477\Pycharm projects\data_process\csvfiles\From the lab\December 2020 ophiolites\proc_airs_kr.xlsx", header=0, index_col=0)
pd.to_datetime(df['Date'], errors='coerce')
# Out:
# Sample_ID
# Proc Air 93                              2017-07-11 22:12:14
# Proc Air 95                              2017-11-17 17:22:28
# Proc Air 98 manifold                                     NaT
# Proc Air 99                              2018-06-03 16:21:11
# Proc Air 101                             2018-05-04 19:38:37
#                                                  ...
# Proc Air 308 sample 2001                 2021-10-24 00:00:00
# Proc Air 311 Sample 2009                 2021-10-28 00:00:00
# Proc Air 312 Sample 2010 (Annie's exp)   2021-10-29 00:00:00
# Laser proc air Sample 2052               2021-11-25 11:46:06
# Proc Air 320 Sample 2071                 2021-06-12 17:18:27
# Name: Date, Length: 136, dtype: datetime64[ns]

# %%
ratio1= '82Kr/84Kr'
ratio2= '130Xe/132Xe'

df = df.dropna(axis = 0, subset=[ratio1, ratio2, 'Date'])
df = df.loc[df[ratio1]< 0.3]
#df = df.loc[df[ratio1]> 250]
df = df.loc[df[ratio2]<0.17]

#df = df.loc[df[ratio2]>0.12]

# %%
#initial plot
fig5 = px.scatter(df, x=df['Date'], y=df[ratio1], log_y=False)
fig5.update_layout(
    title="82Kr/84Kr procedural air standards",
    xaxis_title="Date",
    yaxis_title=ratio1)
fig5.update_layout(yaxis={ 'rangemode': 'tozero'})

fig5.update_yaxes(range=[0.14, 0.26]) 
fig5.update_xaxes

fig5.show()
# Out:
# <div>
#
#
#             <div id="bf604864-6bf4-460d-b167-0cea4d2095b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bf604864-6bf4-460d-b167-0cea4d2095b2")) {
#                     Plotly.newPlot(
#                         'bf604864-6bf4-460d-b167-0cea4d2095b2',
# ...

# %%
#initial plot
fig6 = px.scatter(df, x=df['Date'], y=df[ratio2], log_y=False)
fig6.update_layout(
    title="130Xe/132Xe procedural air standards",
    xaxis_title="Date",
    yaxis_title=ratio2)
fig6.update_layout(yaxis={ 'rangemode': 'tozero'})

fig6.update_yaxes(range=[0.14, 0.17]) 
fig6.update_xaxes


fig6.show()
# Out:
# <div>
#
#
#             <div id="0cecf6ed-2140-4b7f-9b93-c0fb6bd7870f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0cecf6ed-2140-4b7f-9b93-c0fb6bd7870f")) {
#                     Plotly.newPlot(
#                         '0cecf6ed-2140-4b7f-9b93-c0fb6bd7870f',
# ...

# %%
with open('procedural_airs_isotope_ratios.html', 'a') as f:
    f.write(fig.to_html(full_html=False, include_plotlyjs=True))
    f.write(fig1.to_html(full_html=False, include_plotlyjs=True))
    f.write(fig2.to_html(full_html=False, include_plotlyjs=True))
    f.write(fig3.to_html(full_html=False, include_plotlyjs=True))
    f.write(fig4.to_html(full_html=False, include_plotlyjs=True))
    f.write(fig5.to_html(full_html=False, include_plotlyjs=True))
    f.write(fig6.to_html(full_html=False, include_plotlyjs=True))
